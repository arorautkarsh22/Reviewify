# %%
import numpy as np
import pandas as pd
import nltk
import seaborn as sns
import matplotlib.pyplot as plt
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# !pip install wordcloud
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import ngrams
import string
import re
from textblob import TextBlob
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Utkarsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Utkarsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Utkarsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Requirement already satisfied: wordcloud in c:\users\utkarsh\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\utkarsh\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\utkarsh\anaconda3\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\utkarsh\anaconda3\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\utkarsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\utkarsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\utkarsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\utkarsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\utkarsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\utkarsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\utkarsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\utkarsh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
df = pd.read_csv('C:/Users/Utkarsh/Documents/Reviewify/New folder/rawdata.csv')

# %%
df.head()
# Out:
#    Column 1  Course  Curriculum  Faculty  Infrastructure  \
# 0       NaN  B.Tech           1        4               3
# 1       NaN  B.Tech           2        1               1
# 2       NaN  B.Tech           4        4               3
# 3       NaN  B.Tech           1        1               2
# 4       NaN  B.Tech           3        2               3
#
#    College Crowd & Life  Facilities  good value for money refer  \
# 0                     2           4                     4   Yes
# 1                     1           1                     1    No
# 2                     2           3                     4    No
# 3                     1           1                     1    No
# 4                     3           3                     2   Yes
#
#                                               review sentiment
# 0       Dikhaava hai sab. Apni padhai karo aur niklo  Negative
# 1  Only friends are the bestest in this college.....  Negative
# 2                                         It's okay.  Positive
# 3  Very bad experience... This is not a college t...  Negative
# 4  Faculties promised are not delivered,overall e...  Negative

# %%
df= df.drop('Column 1', axis=1)
df.head()
# Out:
#    Course  Curriculum  Faculty  Infrastructure  College Crowd & Life  \
# 0  B.Tech           1        4               3                     2
# 1  B.Tech           2        1               1                     1
# 2  B.Tech           4        4               3                     2
# 3  B.Tech           1        1               2                     1
# 4  B.Tech           3        2               3                     3
#
#    Facilities  good value for money refer  \
# 0           4                     4   Yes
# 1           1                     1    No
# 2           3                     4    No
# 3           1                     1    No
# 4           3                     2   Yes
#
#                                               review sentiment
# 0       Dikhaava hai sab. Apni padhai karo aur niklo  Negative
# 1  Only friends are the bestest in this college.....  Negative
# 2                                         It's okay.  Positive
# 3  Very bad experience... This is not a college t...  Negative
# 4  Faculties promised are not delivered,overall e...  Negative

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Course                81 non-null     object
#  1   Curriculum            81 non-null     int64
#  2   Faculty               81 non-null     int64
#  3   Infrastructure        81 non-null     int64
#  4   College Crowd & Life  81 non-null     int64
#  5   Facilities            81 non-null     int64
#  6   good value for money  81 non-null     int64
#  7   refer                 81 non-null     object
#  8   review                81 non-null     object
#  9   sentiment             81 non-null     object
# dtypes: int64(6), object(4)
# memory usage: 6.5+ KB

# %%
df['review']
# Out:
# 0          Dikhaava hai sab. Apni padhai karo aur niklo
# 1     Only friends are the bestest in this college.....
# 2                                            It's okay.
# 3     Very bad experience... This is not a college t...
# 4     Faculties promised are not delivered,overall e...
#                             ...
# 76                             vey bad no wifi range \n
# 77                                              Average
# 78                                              Average
# 79                            Good learning experience
# 80                                                 Good
# Name: review, Length: 81, dtype: object

# %%
df.isnull().sum()
# Out:
# Course                  0
# Curriculum              0
# Faculty                 0
# Infrastructure          0
# College Crowd & Life    0
# Facilities              0
# good value for money    0
# refer                   0
# review                  0
# sentiment               0
# dtype: int64

# %%
df= df.dropna()
df.isnull().sum()
# Out:
# Course                  0
# Curriculum              0
# Faculty                 0
# Infrastructure          0
# College Crowd & Life    0
# Facilities              0
# good value for money    0
# refer                   0
# review                  0
# sentiment               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, 0 to 80
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Course                80 non-null     object
#  1   Curriculum            80 non-null     int64
#  2   Faculty               80 non-null     int64
#  3   Infrastructure        80 non-null     int64
#  4   College Crowd & Life  80 non-null     int64
#  5   Facilities            80 non-null     int64
#  6   good value for money  80 non-null     int64
#  7   refer                 80 non-null     object
#  8   review                80 non-null     object
#  9   sentiment             80 non-null     object
# dtypes: int64(6), object(4)
# memory usage: 6.9+ KB

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Positive    41
# Negative    39
# Name: count, dtype: int64

# %%
df['Course'].value_counts()
# Out:
# Course
# B.Tech      69
# BCA          6
# BBA          3
# B.Pharma     1
# MBA          1
# Name: count, dtype: int64

# %%
#NLP

# %%
#lowercase
df['review']= df['review'].str.lower()
df['review'].head()
# Out:
# 0         dikhaava hai sab. apni padhai karo aur niklo
# 1    only friends are the bestest in this college.....
# 2                                           it's okay.
# 3    very bad experience... this is not a college t...
# 4    faculties promised are not delivered,overall e...
# Name: review, dtype: object

# %%
#remove whitespaces

df['review'] = df['review'].str.strip()
df['review'].head()
# Out:
# 0         dikhaava hai sab. apni padhai karo aur niklo
# 1    only friends are the bestest in this college.....
# 2                                           it's okay.
# 3    very bad experience... this is not a college t...
# 4    faculties promised are not delivered,overall e...
# Name: review, dtype: object

# %%
#expanding abrrivieations
def remove_abb(data):
     data = re.sub(r"he's", "he is", data)
     data = re.sub(r"there's", "there is", data)
     data = re.sub(r"We're", "We are", data)
     data = re.sub(r"That's", "That is", data)
     data = re.sub(r"won't", "will not", data)
     data = re.sub(r"they're", "they are", data)
     data = re.sub(r"Can't", "Cannot", data)
     data = re.sub(r"wasn't", "was not", data)
     data = re.sub(r"don\x89Ûªt", "do not", data)
     data= re.sub(r"aren't", "are not", data)
     data = re.sub(r"isn't", "is not", data)
     data = re.sub(r"What's", "What is", data)
     data = re.sub(r"haven't", "have not", data)
     data = re.sub(r"hasn't", "has not", data)
     data = re.sub(r"There's", "There is", data)
     data = re.sub(r"He's", "He is", data)
     data = re.sub(r"It's", "It is", data)
     data = re.sub(r"You're", "You are", data)
     data = re.sub(r"I'M", "I am", data)
     data = re.sub(r"shouldn't", "should not", data)
     data = re.sub(r"wouldn't", "would not", data)
     data = re.sub(r"i'm", "I am", data)
     data = re.sub(r"I\x89Ûªm", "I am", data)
     data = re.sub(r"I'm", "I am", data)
     data = re.sub(r"Isn't", "is not", data)
     data = re.sub(r"Here's", "Here is", data)
     data = re.sub(r"you've", "you have", data)
     data = re.sub(r"you\x89Ûªve", "you have", data)
     data = re.sub(r"we're", "we are", data)
     data = re.sub(r"what's", "what is", data)
     data = re.sub(r"couldn't", "could not", data)
     data = re.sub(r"we've", "we have", data)
     data = re.sub(r"it\x89Ûªs", "it is", data)
     data = re.sub(r"doesn\x89Ûªt", "does not", data)
     data = re.sub(r"It\x89Ûªs", "It is", data)
     data = re.sub(r"Here\x89Ûªs", "Here is", data)
     data = re.sub(r"who's", "who is", data)
     data = re.sub(r"I\x89Ûªve", "I have", data)
     data = re.sub(r"y'all", "you all", data)
     data = re.sub(r"can\x89Ûªt", "cannot", data)
     data = re.sub(r"would've", "would have", data)
     data = re.sub(r"it'll", "it will", data)
     data = re.sub(r"we'll", "we will", data)
     data = re.sub(r"wouldn\x89Ûªt", "would not", data)
     data = re.sub(r"We've", "We have", data)
     data = re.sub(r"he'll", "he will", data)
     data = re.sub(r"Y'all", "You all", data)
     data = re.sub(r"Weren't", "Were not", data)
     data = re.sub(r"Didn't", "Did not", data)
     data = re.sub(r"they'll", "they will", data)
     data = re.sub(r"they'd", "they would", data)
     data = re.sub(r"DON'T", "DO NOT", data)
     data = re.sub(r"That\x89Ûªs", "That is", data)
     data = re.sub(r"they've", "they have", data)
     data = re.sub(r"i'd", "I would", data)
     data = re.sub(r"should've", "should have", data)
     data = re.sub(r"You\x89Ûªre", "You are", data)
     data = re.sub(r"where's", "where is", data)
     data = re.sub(r"Don\x89Ûªt", "Do not", data)
     data = re.sub(r"we'd", "we would", data)
     data = re.sub(r"i'll", "I will", data)
     data = re.sub(r"weren't", "were not", data)
     data = re.sub(r"They're", "They are", data)
     data = re.sub(r"Can\x89Ûªt", "Cannot", data)
     data = re.sub(r"you\x89Ûªll", "you will", data)
     data = re.sub(r"I\x89Ûªd", "I would", data)
     data = re.sub(r"let's", "let us", data)
     data = re.sub(r"it's", "it is", data)
     data = re.sub(r"can't", "cannot", data)
     data = re.sub(r"don't", "do not", data)
     data = re.sub(r"you're", "you are", data)
     data = re.sub(r"i've", "I have", data)
     data = re.sub(r"that's", "that is", data)
     data = re.sub(r"i'll", "I will", data)
     data = re.sub(r"doesn't", "does not",data)
     data = re.sub(r"i'd", "I would", data)
     data = re.sub(r"didn't", "did not", data)
     data = re.sub(r"ain't", "am not", data)
     data = re.sub(r"you'll", "you will", data)
     data = re.sub(r"I've", "I have", data)
     data = re.sub(r"Don't", "do not", data)
     data = re.sub(r"I'll", "I will", data)
     data = re.sub(r"I'd", "I would", data)
     data = re.sub(r"Let's", "Let us", data)
     data = re.sub(r"you'd", "You would", data)
     data = re.sub(r"It's", "It is", data)
     data = re.sub(r"Ain't", "am not", data)
     data = re.sub(r"Haven't", "Have not", data)
     data = re.sub(r"Could've", "Could have", data)
     data = re.sub(r"youve", "you have", data)
     data = re.sub(r"donå«t", "do not", data)
     return data

df['review']= df['review'].apply(remove_abb)
df['review']
# Out:
# 0          dikhaava hai sab. apni padhai karo aur niklo
# 1     only friends are the bestest in this college.....
# 2                                           it is okay.
# 3     very bad experience... this is not a college t...
# 4     faculties promised are not delivered,overall e...
#                             ...
# 76                                vey bad no wifi range
# 77                                              average
# 78                                              average
# 79                             good learning experience
# 80                                                 good
# Name: review, Length: 80, dtype: object

# %%
#spelling mistakes correct

def spell_correct(text):
    return TextBlob(str(text)).correct().string

df['review'].apply(spell_correct)
df['review'].head()
# Out:
# 0         dikhaava hai sab. apni padhai karo aur niklo
# 1    only friends are the bestest in this college.....
# 2                                          it is okay.
# 3    very bad experience... this is not a college t...
# 4    faculties promised are not delivered,overall e...
# Name: review, dtype: object

# %%
#removing punctuation

def remove_punctuation(text):
    for i in string.punctuation:
        if i in text:
            text = text.replace(i,'')
    return text 

df['review'] = df['review'].apply(remove_punctuation)

df['review'].head()
# Out:
# 0          dikhaava hai sab apni padhai karo aur niklo
# 1    only friends are the bestest in this college a...
# 2                                           it is okay
# 3    very bad experience this is not a college this...
# 4    faculties promised are not deliveredoverall ex...
# Name: review, dtype: object

# %%
#tokenization
df['tokenized_review'] = df['review'].apply(word_tokenize)
df['tokenized_review'].head()
# Out:
# 0    [dikhaava, hai, sab, apni, padhai, karo, aur, ...
# 1    [only, friends, are, the, bestest, in, this, c...
# 2                                       [it, is, okay]
# 3    [very, bad, experience, this, is, not, a, coll...
# 4    [faculties, promised, are, not, deliveredovera...
# Name: tokenized_review, dtype: object

# %%
#stop words removal
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in text if word.lower() not in stop_words]
    return filtered_words

df['tokenized_review']=df['tokenized_review'].apply(remove_stopwords)

df['tokenized_review'].head()
# Out:
# 0    [dikhaava, hai, sab, apni, padhai, karo, aur, ...
# 1      [friends, bestest, college, basic, things, bad]
# 2                                               [okay]
# 3              [bad, experience, college, small, jail]
# 4    [faculties, promised, deliveredoverall, experi...
# Name: tokenized_review, dtype: object

# %%
#review<--tokenized review
df['review'] = df['tokenized_review'].apply(lambda x:" ".join(x))
df['review'].head()
# Out:
# 0          dikhaava hai sab apni padhai karo aur niklo
# 1             friends bestest college basic things bad
# 2                                                 okay
# 3                    bad experience college small jail
# 4    faculties promised deliveredoverall experience...
# Name: review, dtype: object

# %%
df['char_length'] = df['review'].str.len()
df.head()
# Out:
#    Course  Curriculum  Faculty  Infrastructure  College Crowd & Life  \
# 0  B.Tech           1        4               3                     2
# 1  B.Tech           2        1               1                     1
# 2  B.Tech           4        4               3                     2
# 3  B.Tech           1        1               2                     1
# 4  B.Tech           3        2               3                     3
#
#    Facilities  good value for money refer  \
# 0           4                     4   Yes
# 1           1                     1    No
# 2           3                     4    No
# 3           1                     1    No
# 4           3                     2   Yes
#
#                                               review sentiment  \
# 0        dikhaava hai sab apni padhai karo aur niklo  Negative
# 1           friends bestest college basic things bad  Negative
# 2                                               okay  Positive
# 3                  bad experience college small jail  Negative
# 4  faculties promised deliveredoverall experience...  Negative
#
#                                     tokenized_review  char_length
# 0  [dikhaava, hai, sab, apni, padhai, karo, aur, ...           43
# 1    [friends, bestest, college, basic, things, bad]           40
# 2                                             [okay]            4
# 3            [bad, experience, college, small, jail]           33
# 4  [faculties, promised, deliveredoverall, experi...           65

# %%
#Data Analysis

# %%
df['tokenized_review'].sum()
# Out:
# ['dikhaava',
#  'hai',
#  'sab',
#  'apni',
#  'padhai',
#  'karo',
#  'aur',
#  'niklo',
#  'friends',
#  'bestest',
#  'college',
#  'basic',
#  'things',
#  'bad',
#  'okay',
#  'bad',
#  'experience',
#  'college',
#  'small',
#  'jail',
#  'faculties',
#  'promised',
#  'deliveredoverall',
#  'experience',
#  'horrible',
#  'companies',
#  'great',
#  'experience',
#  'studying',
#  'college',
#  'good',
#  'opportunities',
#  'pathetic',
#  'good',
#  'really',
#  'nothing',
#  'worst',
#  'experience',
#  'teachers',
#  'manners',
#  'speak',
#  'college',
#  'great',
#  'infrastructure',
#  'facilities',
#  'faculty',
#  'much',
#  'experienced',
#  'knowledgeable',
#  'facilities',
#  'available',
#  'per',
#  'amount',
#  'pay',
#  'good',
#  'could',
#  'better',
#  'bad',
#  'okayish',
#  'infrastructure',
#  'good',
#  'summers',
#  'even',
#  'winters',
#  'students',
#  'even',
#  'place',
#  'sit',
#  'recess',
#  'free',
#  'lectures',
#  'roam',
#  'get',
#  'place',
#  'sit',
#  'comfortably',
#  'whenever',
#  'free',
#  'also',
#  'many',
#  'unnecessary',
#  'rules',
#  'like',
#  'u',
#  'even',
#  'cut',
#  'cake',
#  'ur',
#  'friends',
#  'birthday',
#  'celebration',
#  'even',
#  'boy',
#  'girl',
#  'normal',
#  'friends',
#  'sitting',
#  'together',
#  'get',
#  'id',
#  'cards',
#  'impose',
#  'fine',
#  'like',
#  'cmon',
#  'co',
#  'ed',
#  'college',
#  'interact',
#  'colleagues',
#  'teachers',
#  'good',
#  'exposure',
#  'culture',
#  'restrictions',
#  'everything',
#  'studying',
#  'college',
#  'wonderful',
#  'journey',
#  'filled',
#  'learning',
#  'growth',
#  'unforgettable',
#  'memories',
#  'grateful',
#  'supportive',
#  'teachers',
#  'friendships',
#  'made',
#  'along',
#  'way',
#  'good',
#  'much',
#  'great',
#  'study',
#  'yess',
#  'fun',
#  'entertainment',
#  'good',
#  'though',
#  'college',
#  'like',
#  'school',
#  'discipline',
#  'even',
#  'less',
#  'studies',
#  'school',
#  'even',
#  'though',
#  'mainly',
#  'study',
#  'college',
#  'even',
#  'understand',
#  'give',
#  'us',
#  'leu',
#  'attendance',
#  'experience',
#  'quite',
#  'devastating',
#  'good',
#  'clg',
#  'good',
#  'infrastructure',
#  'good',
#  'college',
#  'campus',
#  'clean',
#  'teaching',
#  'materials',
#  'teachers',
#  '95',
#  'bloatwares',
#  'needs',
#  'replaced',
#  'think',
#  'nutral',
#  'option',
#  'given',
#  'mediocre',
#  '’',
#  'four',
#  'years',
#  'education',
#  'four',
#  'seasons',
#  'circus—where',
#  'ringmasters',
#  'management',
#  'clue',
#  'hell',
#  'clowns',
#  'faculty',
#  'kept',
#  'repeating',
#  'old',
#  'tricks',
#  'chained',
#  'animals',
#  'waiting',
#  'act',
#  'end',
#  'nothing',
#  'say',
#  'nothing',
#  'say',
#  'good',
#  'subjects',
#  'punishment',
#  'instead',
#  'bond',
#  'fine',
#  'bond',
#  'fine',
#  'directly',
#  'impact',
#  'parent',
#  'punishment',
#  'impact',
#  'guilty',
#  'good',
#  'average',
#  'awful',
#  'like',
#  'studying',
#  'school',
#  'many',
#  'restrictions',
#  'collecting',
#  'unforgettable',
#  'memories',
#  'piet',
#  'campusthe',
#  'infrastructure',
#  'faculties',
#  'good',
#  'expected',
#  '1',
#  '2',
#  'wifi',
#  'speed',
#  'campus',
#  'goodso',
#  'please',
#  'look',
#  'major',
#  'problem',
#  'college',
#  'offers',
#  'good',
#  'learning',
#  'atmosphere',
#  'helpful',
#  'faculty',
#  'vibrant',
#  'events',
#  'however',
#  'better',
#  'placement',
#  'support',
#  'practical',
#  'exposure',
#  'would',
#  'enhance',
#  'experience',
#  'great',
#  'honest',
#  'sucks',
#  'outdated',
#  'curriculum',
#  'like',
#  'totally',
#  'outdated',
#  'subjects',
#  'make',
#  'sense',
#  'pay',
#  'wifi',
#  'never',
#  'single',
#  'use',
#  'life',
#  'soo',
#  'ass',
#  'one',
#  'even',
#  'get',
#  'spend',
#  'time',
#  'family',
#  'one',
#  'thing',
#  'know',
#  'college',
#  'good',
#  'far',
#  'know',
#  'called',
#  'marketting',
#  'average',
#  'school',
#  'type',
#  'environment',
#  'good',
#  'decentcan',
#  'better',
#  '1st',
#  'year',
#  'good',
#  'however',
#  'nowadays',
#  'college',
#  'life',
#  'help',
#  'build',
#  'character',
#  'depends',
#  'go',
#  'fate',
#  'negative',
#  'course',
#  'good',
#  'medium',
#  'good',
#  'good',
#  'bad',
#  'going',
#  'refer',
#  'anyone',
#  'pretty',
#  'average',
#  'although',
#  'expectations',
#  'high',
#  'coming',
#  'college',
#  'eventually',
#  'went',
#  'college',
#  'offers',
#  'decent',
#  'infrastructure',
#  'vibrant',
#  'crowd',
#  'contributing',
#  'positively',
#  'overall',
#  'experience',
#  'however',
#  'curriculum',
#  'feels',
#  'outdated',
#  'lacks',
#  'industry',
#  'alignment',
#  'affects',
#  'learning',
#  'outcomes',
#  'faculty',
#  'support',
#  'teaching',
#  'quality',
#  'could',
#  'also',
#  'improved',
#  'enriching',
#  'academics',
#  'sometimes',
#  'maybe',
#  'good',
#  'sometimes',
#  'maybe',
#  'shit',
#  'nothing',
#  'good',
#  'teacher',
#  'nice',
#  'worst',
#  'decision',
#  'life',
#  'tbh',
#  'never',
#  'seen',
#  'level',
#  'chapris',
#  'gawar',
#  'college',
#  'campus',
#  'seen',
#  'first',
#  'year',
#  'betch',
#  'giving',
#  'degree',
#  'typo',
#  'people',
#  'know',
#  'manners',
#  'act',
#  'perform',
#  'well',
#  'college',
#  'fighting',
#  'nd',
#  'worst',
#  'department',
#  'ever',
#  'pay',
#  'fees',
#  'give',
#  'shit',
#  'poor',
#  'excellent',
#  'think',
#  'proper',
#  'sitting',
#  'areas',
#  'good',
#  'system',
#  'like',
#  'students',
#  'enter',
#  'leave',
#  'time',
#  'facility',
#  'students',
#  'headache',
#  'complete',
#  '75',
#  'attendance',
#  'think',
#  'less',
#  'strictness',
#  'yesssssss',
#  'strictness',
#  'unappropriate',
#  'people',
#  'think',
#  'open',
#  'friendly',
#  'vibe',
#  'overall',
#  'missing',
#  'lectures',
#  'like',
#  'think',
#  '2',
#  'free',
#  'lectures',
#  'coz',
#  'obvious',
#  'student',
#  'cant',
#  'focus',
#  '7',
#  'hours',
#  'straight',
#  'ridiculous',
#  'good',
#  'great',
#  'colleges',
#  'niceee',
#  'good',
#  'experience',
#  'experience',
#  'average',
#  'good',
#  'good',
#  'college',
#  'studying',
#  'ok',
#  'security',
#  'officer',
#  'many',
#  'teachers',
#  'corporating',
#  'neither',
#  'bad',
#  'good',
#  '😊',
#  'bad',
#  'mid',
#  '’',
#  'great',
#  'experience',
#  'good',
#  'infrastructure',
#  'cooperative',
#  'faculty',
#  'vey',
#  'bad',
#  'wifi',
#  'range',
#  'average',
#  'average',
#  'good',
#  'learning',
#  'experience',
#  'good']

# %%
pd.Series(ngrams(df['tokenized_review'].sum(),2)).value_counts()
# Out:
# (sometimes, maybe)          2
# (great, experience)         2
# (place, sit)                2
# (infrastructure, good)      2
# (good, good)                2
#                            ..
# (quite, devastating)        1
# (experience, quite)         1
# (attendance, experience)    1
# (leu, attendance)           1
# (learning, experience)      1
# Name: count, Length: 483, dtype: int64

# %%
plt.figure(figsize=(20,20))
wc = WordCloud(width=1600, height=800).generate("".join(df['review']))
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot( x='Faculty', data=df,palette="dark:salmon_r")
sns.set_style("dark")
plt.title("Satisfaction Levels of Students with Faculty")
plt.xlabel("Ratings")
plt.ylabel("Number of students")
plt.show()
# Out:
# C:\Users\Utkarsh\AppData\Local\Temp\ipykernel_23172\2331044744.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( x='Faculty', data=df,palette="dark:salmon_r")

# %%
plt.figure(figsize=(12, 8))
sns.countplot( x='Curriculum', data=df,palette="dark:salmon_r")
sns.set_style("dark")
plt.title("Satisfaction Levels of Students with Curriculum")
plt.xlabel("Ratings")
plt.ylabel("Number of students")
plt.show()
# Out:
# C:\Users\Utkarsh\AppData\Local\Temp\ipykernel_23172\2880284324.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( x='Curriculum', data=df,palette="dark:salmon_r")

# %%
plt.figure(figsize=(12, 8))
sns.countplot( x='Infrastructure', data=df,palette="dark:salmon_r")
sns.set_style("dark")
plt.title("Satisfaction Levels of Students with Infrastructure")
plt.xlabel("Ratings")
plt.ylabel("Number of students")
plt.show()
# Out:
# C:\Users\Utkarsh\AppData\Local\Temp\ipykernel_23172\187729054.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( x='Infrastructure', data=df,palette="dark:salmon_r")

# %%
plt.figure(figsize=(12, 8))
sns.countplot( x='College Crowd & Life', data=df,palette="dark:salmon_r")
sns.set_style("dark")
plt.title("Satisfaction Levels of Students with College Crowd & Life")
plt.xlabel("Ratings")
plt.ylabel("Number of students")
plt.show()
# Out:
# C:\Users\Utkarsh\AppData\Local\Temp\ipykernel_23172\3994126440.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( x='College Crowd & Life', data=df,palette="dark:salmon_r")

# %%
plt.figure(figsize=(12, 8))
sns.countplot( x='Facilities', data=df,palette="dark:salmon_r")
sns.set_style("dark")
plt.title("Satisfaction Levels of Students with Facilities")
plt.xlabel("Ratings")
plt.ylabel("Number of students")
plt.show()
# Out:
# C:\Users\Utkarsh\AppData\Local\Temp\ipykernel_23172\2977741914.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( x='Facilities', data=df,palette="dark:salmon_r")

# %%
plt.figure(figsize=(12, 8))
sns.countplot( x='good value for money', data=df,palette="dark:salmon_r")
sns.set_style("dark")
plt.title("Are the students satisfied with the amount of money college takes")
plt.xlabel("Satisfaction Levels")
plt.ylabel("Number of students")
plt.show()
# Out:
# C:\Users\Utkarsh\AppData\Local\Temp\ipykernel_23172\397569823.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( x='good value for money', data=df,palette="dark:salmon_r")

# %%
plt.figure(figsize=(12, 8))
sns.countplot( x='refer', data=df,palette="dark:salmon_r")
sns.set_style("dark")
plt.title("Would the students of PIET refer their college to thers")
plt.xlabel("")
plt.ylabel("Number of students")
plt.show()
# Out:
# C:\Users\Utkarsh\AppData\Local\Temp\ipykernel_23172\4250741124.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( x='refer', data=df,palette="dark:salmon_r")
